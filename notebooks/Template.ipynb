# %%
# Auto-reload: actively reload all imported modules and packages as they are modified
# %load_ext autoreload
# %autoreload 2

# %%
# %reload_ext autoreload

# %%
from PyPDF2 import PdfReader

# %%
from scream_fest_analytics.example import some_method

# %%
some_method()
# Out:
# 2022-11-12 06:48:17.167 | INFO     | scream_fest_analytics.example:some_method:5 - Hit some_method!
# 'Method working'

# %%
! printenv
# Out:
# SHELL=/bin/bash
# HOSTNAME=7ebb290b7659
# LANGUAGE=en_US.UTF-8
# NB_UID=1000
# PWD=/home/jovyan
# PACKAGE_NAME=scream_fest_analytics
# GRANT_SUDO=yes
# JUPYTER_CONTAINER_PORT=8888
# JUPYTER_LOCALHOST_PORT=8888
# HOME=/home/jovyan
# LANG=en_US.UTF-8
# NB_GID=100
# CLICOLOR=1
# JPY_PARENT_PID=8
# PYTHONPATH=:/home/app/src
# TERM=xterm-color
# GIT_PAGER=cat
# SHLVL=0
# PAGER=cat
# CONDA_DIR=/opt/conda
# MPLBACKEND=module://matplotlib_inline.backend_inline
# NB_USER=jovyan
# LC_ALL=en_US.UTF-8
# PATH=/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin
# DEBIAN_FRONTEND=noninteractive
# _=/usr/bin/printenv

# %%
! ls -la ../app/
# Out:
# total 28
# drwxr-xr-x 14 root   root   448 Nov 12 06:21 .
# drwxr-xr-x  1 root   root  4096 Nov 12 05:42 ..
# drwxr-xr-x  7 jovyan users  224 Nov 12 05:43 bin
# drwxr-xr-x  7 jovyan users  224 Nov 12 06:43 data
# -rwxr-xr-x  1 jovyan users  563 Nov 12 05:39 Dockerfile
# -rw-r--r--  1 jovyan users   90 Nov 12 06:04 .env
# drwxr-xr-x 12 jovyan users  384 Nov 12 05:35 .git
# -rwxr-xr-x  1 jovyan users 1966 Nov 12 05:08 .gitignore
# drwxr-xr-x 10 jovyan users  320 Nov 12 06:50 notebooks
# drwxr-xr-x  6 jovyan users  192 Nov 12 06:03 .pytest_cache
# -rw-r--r--  1 jovyan users 1087 Nov 12 06:35 README.md
# -rwxr-xr-x  1 jovyan users  692 Nov 12 06:20 setup.py
# drwxr-xr-x  3 jovyan users   96 Nov 12 05:40 src
# drwxr-xr-x  4 jovyan users  128 Nov 12 06:36 tests

# %%
! pip install PyPDF2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.4/220.4 kB 2.9 MB/s eta 0:00:0000:0100:01
# ...

# %%
reader = PdfReader("../app/data/Scream3.pdf")
text = ""
for page in reader.pages:
    text += page.extract_text() + "\n"

# %%
print(text)
# Out:
# SCREAM 3EHREN KRUGER2nd DRAFT - REVISEDMAY 2, 1999FADE IN:A big dramatic crescendo as we --OPEN ON:EXT.  HOLLYWOOD FREEWAY - SUNSET - AERIALFriday night traffic as usual. Things appear to be backed up all the way to the valley. A cacophony of car horns rise up on the soundtrack as we slowly DISSOLVE INTO:INT.  FORD EXPLORER - NIGHTA new 99' Explorer sits in the midst of the gridlock. Behind the wheel is hot teen heartthrob and Hollywood everybody BEN DAMON. Ben is handsome, studly, in his early 20s. However, aside from being just another pretty face in the city of angels he's also a cocky, arrogant prick. Ben's in the middle of a heated argument on his cell with his Agent, Cathy. BEN(into cell)God dammit Cathy I have no time for this crap!I'm supposed to be at the premiere of STAB 2 rightNow, arm and arm with my girlfriend cause she's gota bit part in that over advertised piece of shit andI'm just going to humor her. You mena to tell me thatin all your squandering the best you can do
# ...
